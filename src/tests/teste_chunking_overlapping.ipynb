# %%
import os
import pandas as pd
from langchain_community.document_loaders import CSVLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
df = pd.read_csv(r'C:\Users\Diane Alves\Desktop\BACK-DOMROCK\src\data\chat_data.csv')

# %%
print(df.columns)
# Out:
# Index(['submission_date', 'reviewer_id', 'product_id', 'product_name',
#        'product_brand', 'site_category_lv1', 'site_category_lv2',
#        'review_title', 'overall_rating', 'recommend_to_a_friend',
#        'review_text', 'reviewer_birth_year', 'reviewer_gender',
#        'reviewer_state'],
#       dtype='object')

# %%
# define as colunas do csv que serão usadas
useful_data = ['product_name', 'product_brand', 'site_category_lv1', 'site_category_lv2', 'overall_rating', 'review_text', 'reviewer_gender', 'submission_date', 'reviewer_birth_year']

# %%
# carrega o csv
def load_data(file_path):
    # lê o arquivo csv
    df = pd.read_csv(file_path)
    
    # exclui as colunas que não serão usadas
    df_reduced = df.drop(columns=[col for col in df.columns if col not in useful_data])

    # limpa e normaliza o texto
    for column in useful_data:
        df_reduced[column] = df_reduced[column].apply(lambda x: normalize_text(str(x)))
        df_reduced[column] = df_reduced[column].apply(lambda x: remove_stopwords(str(x)))

    # define o nome e o caminho do arquivo de saída
    result_file_name = 'data_processed.csv'  # nome do arquivo de saída
    new_file_path = os.path.join('data', result_file_name)  # caminho para salvar o arquivo de saída na pasta 'data'
    
    # salva os dados em csv
    df_reduced.to_csv(new_file_path, index=False)

    return new_file_path

# %%
# define o nome e o caminho do arquivo de saída
result_file_name = 'data_processed.csv'  # nome do arquivo de saída
new_file_path = os.path.join('data', result_file_name)  # caminho para salvar o arquivo de saída na pasta

# %%
# Retorna o caminho do arquivo gerado
print(f'Arquivo salvo em: {new_file_path}')
# Out:
# Arquivo salvo em: data\data_processed.csv

# %%
def load_and_chunk(file_path):
    # gera os documentos com o csv processado
    loader = CSVLoader(file_path=file_path, encoding='utf-8', csv_args={
        'delimiter': ',', 'quotechar': '"', 'fieldnames': useful_data
    }) # classe do langchain para manipular os dados
    # delimiter define o que separa as colunas do csv (no caso, uma vírgula)
    # quotechar define o caractere que envolve strings, permitindo que uma string tenha vírgulas sem ser divididas em colunas
    # fieldnames são os nomes das colunas que serão carregadas

    docs = loader.load() # retorna os documentos gerados

    # chunkeniza e adiciona overlap nos dados
    # text_splitter = RecursiveCharacterTextSplitter(chunk_size=800, chunk_overlap=150)
    # text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1050, chunk_overlap=250)
    splits = text_splitter.split_documents(docs)

    return splits

# %%
# Caminho do arquivo processado (assumindo que você já gerou o arquivo com a função anterior)
processed_file_path = r'C:\Users\Diane Alves\Desktop\BACK-DOMROCK\src\data\chat_data.csv'

# Chama a função e armazena os splits retornados
splits = load_and_chunk(processed_file_path)

# Exibe os resultados
print(splits)
# Out:
# [Document(metadata={'source': 'C:\\Users\\Diane Alves\\Desktop\\BACK-DOMROCK\\src\\data\\chat_data.csv', 'row': 0}, page_content='product_name: submission_date\nproduct_brand: reviewer_id\nsite_category_lv1: product_id\nsite_category_lv2: product_name\noverall_rating: product_brand\nreview_text: site_category_lv1\nreviewer_gender: site_category_lv2\nsubmission_date: review_title\nreviewer_birth_year: overall_rating\nNone: recommend_to_a_friend,review_text,reviewer_birth_year,reviewer_gender,reviewer_state'), Document(metadata={'source': 'C:\\Users\\Diane Alves\\Desktop\\BACK-DOMROCK\\src\\data\\chat_data.csv', 'row': 1}, page_content='product_name: 2018-01-01 00:11:28\nproduct_brand: d0fb1ca69422530334178f5c8624aa7a99da47907c44de0243719b15d50623ce\nsite_category_lv1: 132532965\nsite_category_lv2: Notebook Asus Vivobook Max X541NA-GO472T Intel Celeron Quad Core 4GB 500GB Tela LED 15,6" Windows - 10 Branco\noverall_rating: \nreview_text: Informática\nreviewer_gender: Notebook\nsubmission_date: Bom\nreviewer_birth_year: 4\nNone: Yes,Estou contente com a compra entrega rápida o único problema com as Americanas é se houver troca ou devolução do produto o consumidor tem problemas com espera.,1958.0,F,RJ'), Document(metadata={'source': 'C:\\Users\\Diane Alves\\Desktop\\BACK-DOMROCK\\src\\data\\chat_data.csv', 'row': 2}, page_content='product_name: 2018-01-01 00:13:48\nproduct_brand: 014d6dc5a10aed1ff1e6f349fb2b059a2d3de511c7538a9008da562ead5f5ecd\nsite_category_lv1: 22562178\nsite_category_lv2: Copo Acrílico Com Canudo 500ml Rocie\noverall_rating: \nreview_text: Utilidades Domésticas\nreviewer_gender: Copos, Taças e Canecas\nsubmission_date: Preço imbatível, ótima qualidade\nreviewer_birth_year: 4\nNone: Yes,Por apenas R$1994.20,eu consegui comprar esse lindo copo de acrílico.,1996.0,M,SC'), Document(metadata={'source': 'C:\\Users\\Diane Alves\\Desktop\\BACK-DOMROCK\\src\\data\\chat_data.csv', 'row': 3}, page_content='product_name: 2018-01-01 00:26:02\nproduct_brand: 44f2c8edd93471926fff601274b8b2b5c4824e386ae4f210329b9b71890277fd\nsite_category_lv1: 113022329\nsite_category_lv2: Panela de Pressão Elétrica Philips Walita Daily 5L com Timer\noverall_rating: philips walita\nreview_text: Eletroportáteis\nreviewer_gender: Panela Elétrica\nsubmission_date: ATENDE TODAS AS EXPECTATIVA.\nreviewer_birth_year: 4\nNone: Yes,SUPERA EM AGILIDADE E PRATICIDADE OUTRAS PANELAS ELÉTRICAS.  COSTUMO USAR OUTRA PANELA PARA COZIMENTO DE ARROZ (JAPONESA), MAS LEVA MUITO TEMPO,  +/- 50 MINUTOS.  NESSA PANELA  É MUITO MAIS RÁPIDO, EXATAMENTE 6 MINUTOS.    EU RECOMENDO.,1984.0,M,SP'), Document(metadata={'source': 'C:\\Users\\Diane Alves\\Desktop\\BACK-DOMROCK\\src\\data\\chat_data.csv', 'row': 4}, page_content='product_name: 2018-01-01 00:35:54\nproduct_brand: ce741665c1764ab2d77539e18d0e4f66dde6213c9f0863f165ffedb1e8147984\nsite_category_lv1: 113851581\nsite_category_lv2: Betoneira Columbus - Roma Brinquedos\noverall_rating: roma jensen\nreview_text: Brinquedos\nreviewer_gender: Veículos de Brinquedo\nsubmission_date: presente mais que desejado\nreviewer_birth_year: 4\nNone: Yes,MEU FILHO AMOU! PARECE DE VERDADE COM TANTOS DETALHES QUE TÊM!,1985.0,F,SP'), Document(metadata={'source': 'C:\\Users\\Diane Alves\\Desktop\\BACK-DOMROCK\\src\\data\\chat_data.csv', 'row': 5}, page_content='product_name: 2018-01-01 01:00:28\nproduct_brand: 7d7b6b18dda804a897359276cef0ca252f9932bf4b5c8e72bce7e88850efa0fc\nsite_category_lv1: 131788803\nsite_category_lv2: Smart TV LED 43" LG 43UJ6525 Ultra HD 4K com Conversor Digital 4 HDMI 2 USB WebOS 3.5 Painel Ips HDR e Magic Mobile Connection\noverall_rating: lg\nreview_text: TV e Home Theater\nreviewer_gender: TV\nsubmission_date: Sem duvidas, excelente\nreviewer_birth_year: 5\nNone: Yes,A entrega foi no prazo, as americanas estão de parabéns. A smart tv é muito boa, a navegação na internete e pelos aplicativos e excelente, não trava, sem falar da imagem que é de surpreender. recomendo.,1994.0,M,MG'), Document(metadata={'source': ...

# %%
# Exibe apenas os primeiros 5 splits
for i, split in enumerate(splits[:5]):
    print(f"Split {i + 1}:\n{split}\n")
# Out:
# Split 1:
# page_content='product_name: submission_date
# product_brand: reviewer_id
# site_category_lv1: product_id
# site_category_lv2: product_name
# overall_rating: product_brand
# review_text: site_category_lv1
# reviewer_gender: site_category_lv2
# submission_date: review_title
# reviewer_birth_year: overall_rating
# None: recommend_to_a_friend,review_text,reviewer_birth_year,reviewer_gender,reviewer_state' metadata={'source': 'C:\\Users\\Diane Alves\\Desktop\\BACK-DOMROCK\\src\\data\\chat_data.csv', 'row': 0}
#
# Split 2:
# page_content='product_name: 2018-01-01 00:11:28
# product_brand: d0fb1ca69422530334178f5c8624aa7a99da47907c44de0243719b15d50623ce
# site_category_lv1: 132532965
# site_category_lv2: Notebook Asus Vivobook Max X541NA-GO472T Intel Celeron Quad Core 4GB 500GB Tela LED 15,6" Windows - 10 Branco
# overall_rating:
# review_text: Informática
# reviewer_gender: Notebook
# submission_date: Bom
# reviewer_birth_year: 4
# None: Yes,Estou contente com a compra entrega rápida o único problema com as Americanas é se houver troca ou devolução do produto o consumidor tem problemas com espera.,1958.0,F,RJ' metadata={'source': 'C:\\Users\\Diane Alves\\Desktop\\BACK-DOMROCK\\src\\data\\chat_data.csv', 'row': 1}
#
# Split 3:
# page_content='product_name: 2018-01-01 00:13:48
# product_brand: 014d6dc5a10aed1ff1e6f349fb2b059a2d3de511c7538a9008da562ead5f5ecd
# site_category_lv1: 22562178
# site_category_lv2: Copo Acrílico Com Canudo 500ml Rocie
# overall_rating:
# review_text: Utilidades Domésticas
# reviewer_gender: Copos, Taças e Canecas
# submission_date: Preço imbatível, ótima qualidade
# reviewer_birth_year: 4
# None: Yes,Por apenas R$1994.20,eu consegui comprar esse lindo copo de acrílico.,1996.0,M,SC' metadata={'source': 'C:\\Users\\Diane Alves\\Desktop\\BACK-DOMROCK\\src\\data\\chat_data.csv', 'row': 2}
#
# Split 4:
# page_content='product_name: 2018-01-01 00:26:02
# product_brand: 44f2c8edd93471926fff601274b8b2b5c4824e386ae4f210329b9b71890277fd
# site_category_lv1: 113022329
# site_category_lv2: Panela de Pressão Elétrica Philips Walita Daily 5L com Timer
# overall_rating: philips walita
# review_text: Eletroportáteis
# reviewer_gender: Panela Elétrica
# submission_date: ATENDE TODAS AS EXPECTATIVA.
# reviewer_birth_year: 4
# None: Yes,SUPERA EM AGILIDADE E PRATICIDADE OUTRAS PANELAS ELÉTRICAS.  COSTUMO USAR OUTRA PANELA PARA COZIMENTO DE ARROZ (JAPONESA), MAS LEVA MUITO TEMPO,  +/- 50 MINUTOS.  NESSA PANELA  É MUITO MAIS RÁPIDO, EXATAMENTE 6 MINUTOS.    EU RECOMENDO.,1984.0,M,SP' metadata={'source': 'C:\\Users\\Diane Alves\\Desktop\\BACK-DOMROCK\\src\\data\\chat_data.csv', 'row': 3}
#
# Split 5:
# page_content='product_name: 2018-01-01 00:35:54
# product_brand: ce741665c1764ab2d77539e18d0e4f66dde6213c9f0863f165ffedb1e8147984
# site_category_lv1: 113851581
# site_category_lv2: Betoneira Columbus - Roma Brinquedos
# overall_rating: roma jensen
# review_text: Brinquedos
# reviewer_gender: Veículos de Brinquedo
# submission_date: presente mais que desejado
# reviewer_birth_year: 4
# None: Yes,MEU FILHO AMOU! PARECE DE VERDADE COM TANTOS DETALHES QUE TÊM!,1985.0,F,SP' metadata={'source': 'C:\\Users\\Diane Alves\\Desktop\\BACK-DOMROCK\\src\\data\\chat_data.csv', 'row': 4}
